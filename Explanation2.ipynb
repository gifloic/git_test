# %% [markdown]
# ### Hma a créé directement un fichier banana.txt sur github simulant la création d'une nouvelle branche par un collègue...

# %% [markdown]
# ![image.png](./branch.PNG)

# %% [markdown]
# #### Malheureusement, je n'arrive pas à récupérer l'autre branche, je continue en ajoutant quelques modifs
#
# ![image.png](./graph.PNG)

# %% [markdown]
# #### Voici le fichier après un commit version 10
#
# ![image.png](./graph_v10.PNG)

# %% [markdown]
# #### J'ai dû faire un git enforce origin main
# ![image.png](attachment:graph_v11.PNG)

# %% [markdown]
# ![image.png](./reflog_fin.PNG)
